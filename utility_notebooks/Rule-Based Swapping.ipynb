# %%
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
import pandas as pd

import os
import time
import gc
# Out:
# Mounted at /content/drive

# %%
test = pd.read_csv('/content/drive/MyDrive/data/result_embed.csv')
test.head()
# Out:
#                      ID  Family         0         1         2         3  \
# 0  01kcPWA9K2BOxQeS5Rju       1 -0.338611  1.291727  0.118837 -1.118286
# 1  04EjIdbPV5e1XroFOpiN       1 -0.428330  1.376984  0.234024 -0.627847
# 2  05EeG39MTRrI6VY21DPd       1 -0.377473  1.542212  0.202506 -0.368294
# 3  05rJTUWYAKNegBk2wE8X       1 -0.354789  1.304047  0.117015 -0.903091
# 4  0AnoOZDNbPXIr2MRBSCJ       1 -0.175248  1.296375 -0.155661 -0.533257
#
#           4         5         6         7  ...        90        91        92  \
# 0  0.183966 -0.405247 -0.729886 -0.332307  ... -0.475346 -0.425257 -0.000070
# 1  0.213055 -0.609343 -0.659496 -0.320076  ... -0.408290 -0.389868 -0.164271
# 2  0.447894 -0.722350 -0.336275 -0.411114  ... -0.553859 -0.478773 -0.139812
# 3  0.150693 -0.642379 -0.896521 -0.305303  ... -0.351606 -0.341613 -0.220712
# 4  0.156963 -0.595596 -0.341953 -0.253579  ... -0.324669 -0.036423 -0.272495
#
# ...

# %%
test2 = pd.read_csv('/content/drive/MyDrive/data/dataset.csv')
test2.head()
# Out:
#                      ID                                            Opcodes  \
# 0  Hz8NEvBRqL31AdfQgmFn  push,mov,push,push,push,call,mov,add,test,jnz,...
# 1  2LR1cT43f809ZG6KUd5l  mov,lea,push,or,jmp,mov,inc,mov,inc,add,jnz,mo...
# 2  5DumcTR1Yk7N9FICzSBe  mov,jmp,push,mov,mov,call,test,jz,push,call,ad...
# 3  a7sedvqXEgJMYwAIo93j  mov,push,mov,sub,lea,adc,push,push,call,add,po...
# 4  JK7liDHzL1AIfrPCcFTZ  push,lea,push,mov,call,mov,mov,pop,retn,mov,jm...
#
#    Family
# 0       1
# 1       8
# 2       2
# 3       3
# 4       2

# %%
test2= pd.DataFrame(test['ID']).merge(test2, on='ID').reset_index(drop = True)
test2['Opcodes'] = test2['Opcodes'].apply(lambda x: str(x).replace(',',' '))
test2.head()
# Out:
#                      ID                                            Opcodes  \
# 0  01kcPWA9K2BOxQeS5Rju  push push mov push mov sub mov push push lea m...
# 1  04EjIdbPV5e1XroFOpiN  push push mov push mov mov mov lea push retn m...
# 2  05EeG39MTRrI6VY21DPd  push mov mov test mov jz push call mov test jz...
# 3  05rJTUWYAKNegBk2wE8X  cmp jnz test jnz retn mov push mov mov push mo...
# 4  0AnoOZDNbPXIr2MRBSCJ  push mov sub mov and and push push mov cmp mov...
#
#    Family
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
import pandas as pd

# Assuming your dataframe is named test2
# You can use the apply function along with a custom function to insert "push" instructions
def insert_push(row):
    opcodes = row['Opcodes'].split()
    new_opcodes = []

    for opcode in opcodes:
        new_opcodes.append(opcode)
        if opcode.lower() == 'push':
          new_opcodes.append('pushs')
    return ' '.join(new_opcodes)

def insert_or(row):
    opcodes = row['Opcodes'].split()
    new_opcodes = []

    for opcode in opcodes:
        new_opcodes.append(opcode)
        if opcode.lower() == 'xor':
          new_opcodes.append('or')
    return ' '.join(new_opcodes)

# Apply the function to the 'Opcodes' column
test2['Opcodes'] = test2.apply(insert_push, axis=1)
test2['Opcodes'] = test2.apply(insert_or, axis=1)

# Display the updated dataframe
test2.head()
# Out:
#                      ID                                            Opcodes  \
# 0  01kcPWA9K2BOxQeS5Rju  push pushs push pushs mov push pushs mov sub m...
# 1  04EjIdbPV5e1XroFOpiN  push pushs push pushs mov push pushs mov mov m...
# 2  05EeG39MTRrI6VY21DPd  push pushs mov mov test mov jz push pushs call...
# 3  05rJTUWYAKNegBk2wE8X  cmp jnz test jnz retn mov push pushs mov mov p...
# 4  0AnoOZDNbPXIr2MRBSCJ  push pushs mov sub mov and and push pushs push...
#
#    Family
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
test2.to_csv('/content/drive/MyDrive/adversary_dataset.csv', index=False)
